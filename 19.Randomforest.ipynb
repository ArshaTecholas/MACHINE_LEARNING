# %% [markdown]
# # To convert weak models into strong models - ensemble learning

# %% [markdown]
# # Bagging approach - RandomForestClassifier,RandomForestRegressor
# # Random Forest il ellam DecisionTree aayirikum

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from word2number import w2n

# %%
data = pd.read_csv(r"C:\Users\ARUN\Downloads\automobile.csv")
data
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
data.shape
# Out:
# (61, 10)

# %%
data.dtypes
# Out:
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
data["body-style"].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
data.fillna(0,inplace= True)

# %%
data.isna().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
ab=LabelEncoder()

# %%
data["company"]=ab.fit_transform(data["company"])
data
# Out:
#     index  company   body-style  wheel-base  length engine-type  \
# 0       0        0  convertible        88.6   168.8        dohc
# 1       1        0  convertible        88.6   168.8        dohc
# 2       2        0    hatchback        94.5   171.2        ohcv
# 3       3        1        sedan        99.8   176.6         ohc
# 4       4        1        sedan        99.4   176.6         ohc
# ..    ...      ...          ...         ...     ...         ...
# 56     81       14        sedan        97.3   171.7         ohc
# 57     82       14        sedan        97.3   171.7         ohc
# 58     86       14        sedan        97.3   171.7         ohc
# 59     87       15        sedan       104.3   188.8         ohc
# 60     88       15        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# 1              four         111               21  16500.0
# ...

# %%
data["body-style"]=ab.fit_transform(data["body-style"])
data
# Out:
#     index  company  body-style  wheel-base  length engine-type  \
# 0       0        0           0        88.6   168.8        dohc
# 1       1        0           0        88.6   168.8        dohc
# 2       2        0           2        94.5   171.2        ohcv
# 3       3        1           3        99.8   176.6         ohc
# 4       4        1           3        99.4   176.6         ohc
# ..    ...      ...         ...         ...     ...         ...
# 56     81       14           3        97.3   171.7         ohc
# 57     82       14           3        97.3   171.7         ohc
# 58     86       14           3        97.3   171.7         ohc
# 59     87       15           3       104.3   188.8         ohc
# 60     88       15           4       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# 1              four         111               21  16500.0
# ...

# %%
data["engine-type"]=ab.fit_transform(data["engine-type"])
data
# Out:
#     index  company  body-style  wheel-base  length  engine-type  \
# 0       0        0           0        88.6   168.8            0
# 1       1        0           0        88.6   168.8            0
# 2       2        0           2        94.5   171.2            5
# 3       3        1           3        99.8   176.6            3
# 4       4        1           3        99.4   176.6            3
# ..    ...      ...         ...         ...     ...          ...
# 56     81       14           3        97.3   171.7            3
# 57     82       14           3        97.3   171.7            3
# 58     86       14           3        97.3   171.7            3
# 59     87       15           3       104.3   188.8            3
# 60     88       15           4       104.3   188.8            3
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# 1              four         111               21  16500.0
# ...

# %%
from word2number import w2n

# %%
#pip install word2number

# %%
data['num-of-cylinders']=data['num-of-cylinders'].apply(w2n.word_to_num)
data
# Out:
#     index  company  body-style  wheel-base  length  engine-type  \
# 0       0        0           0        88.6   168.8            0
# 1       1        0           0        88.6   168.8            0
# 2       2        0           2        94.5   171.2            5
# 3       3        1           3        99.8   176.6            3
# 4       4        1           3        99.4   176.6            3
# ..    ...      ...         ...         ...     ...          ...
# 56     81       14           3        97.3   171.7            3
# 57     82       14           3        97.3   171.7            3
# 58     86       14           3        97.3   171.7            3
# 59     87       15           3       104.3   188.8            3
# 60     88       15           4       104.3   188.8            3
#
#     num-of-cylinders  horsepower  average-mileage    price
# 0                  4         111               21  13495.0
# 1                  4         111               21  16500.0
# ...

# %%
x = data.drop(["price"],axis=1)
y = data["price"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=6)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
model=RandomForestRegressor(n_estimators=23,random_state=90)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8841591914002335

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([25340.95652174, 17411.        , 15565.43478261, 20057.2173913 ,
#        36488.26086957,   842.56521739,  8377.08695652,  9063.43478261,
#         6475.43478261,  6960.56521739, 16011.86956522,  6335.91304348,
#         6227.86956522, 19717.47826087, 24458.60869565, 13476.13043478])

# %% [markdown]
# # Classification

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()
digits
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
print(digits.DESCR)
# Out:
# .. _digits_dataset:
#
# Optical recognition of handwritten digits dataset
# --------------------------------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 1797
# :Number of Attributes: 64
# :Attribute Information: 8x8 image of integer pixels in the range 0..16.
# :Missing Attribute Values: None
# :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)
# :Date: July; 1998
#
# This is a copy of the test set of the UCI ML hand-written digits datasets
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits
#
# The data set contains images of hand-written digits: 10 classes where
# each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract
# normalized bitmaps of handwritten digits from a preprinted form. From a
# total of 43 people, 30 contributed to the training set and different 13
# to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of
# ...

# %%
digits.feature_names
# Out:
# ['pixel_0_0',
#  'pixel_0_1',
#  'pixel_0_2',
#  'pixel_0_3',
#  'pixel_0_4',
#  'pixel_0_5',
#  'pixel_0_6',
#  'pixel_0_7',
#  'pixel_1_0',
#  'pixel_1_1',
#  'pixel_1_2',
#  'pixel_1_3',
#  'pixel_1_4',
#  'pixel_1_5',
#  'pixel_1_6',
#  'pixel_1_7',
#  'pixel_2_0',
#  'pixel_2_1',
#  'pixel_2_2',
#  'pixel_2_3',
#  'pixel_2_4',
#  'pixel_2_5',
#  'pixel_2_6',
#  'pixel_2_7',
#  'pixel_3_0',
#  'pixel_3_1',
#  'pixel_3_2',
#  'pixel_3_3',
#  'pixel_3_4',
#  'pixel_3_5',
#  'pixel_3_6',
#  'pixel_3_7',
#  'pixel_4_0',
#  'pixel_4_1',
#  'pixel_4_2',
#  'pixel_4_3',
#  'pixel_4_4',
#  'pixel_4_5',
#  'pixel_4_6',
#  'pixel_4_7',
#  'pixel_5_0',
#  'pixel_5_1',
#  'pixel_5_2',
#  'pixel_5_3',
#  'pixel_5_4',
#  'pixel_5_5',
#  'pixel_5_6',
#  'pixel_5_7',
#  'pixel_6_0',
#  'pixel_6_1',
#  'pixel_6_2',
#  'pixel_6_3',
#  'pixel_6_4',
#  'pixel_6_5',
#  'pixel_6_6',
#  'pixel_6_7',
#  'pixel_7_0',
#  'pixel_7_1',
#  'pixel_7_2',
#  'pixel_7_3',
#  'pixel_7_4',
#  'pixel_7_5',
# ...

# %%
digits.feature_names
# Out:
# ['pixel_0_0',
#  'pixel_0_1',
#  'pixel_0_2',
#  'pixel_0_3',
#  'pixel_0_4',
#  'pixel_0_5',
#  'pixel_0_6',
#  'pixel_0_7',
#  'pixel_1_0',
#  'pixel_1_1',
#  'pixel_1_2',
#  'pixel_1_3',
#  'pixel_1_4',
#  'pixel_1_5',
#  'pixel_1_6',
#  'pixel_1_7',
#  'pixel_2_0',
#  'pixel_2_1',
#  'pixel_2_2',
#  'pixel_2_3',
#  'pixel_2_4',
#  'pixel_2_5',
#  'pixel_2_6',
#  'pixel_2_7',
#  'pixel_3_0',
#  'pixel_3_1',
#  'pixel_3_2',
#  'pixel_3_3',
#  'pixel_3_4',
#  'pixel_3_5',
#  'pixel_3_6',
#  'pixel_3_7',
#  'pixel_4_0',
#  'pixel_4_1',
#  'pixel_4_2',
#  'pixel_4_3',
#  'pixel_4_4',
#  'pixel_4_5',
#  'pixel_4_6',
#  'pixel_4_7',
#  'pixel_5_0',
#  'pixel_5_1',
#  'pixel_5_2',
#  'pixel_5_3',
#  'pixel_5_4',
#  'pixel_5_5',
#  'pixel_5_6',
#  'pixel_5_7',
#  'pixel_6_0',
#  'pixel_6_1',
#  'pixel_6_2',
#  'pixel_6_3',
#  'pixel_6_4',
#  'pixel_6_5',
#  'pixel_6_6',
#  'pixel_6_7',
#  'pixel_7_0',
#  'pixel_7_1',
#  'pixel_7_2',
#  'pixel_7_3',
#  'pixel_7_4',
#  'pixel_7_5',
# ...

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.data[143]
# Out:
# array([ 0.,  6., 16., 16., 15.,  7.,  0.,  0.,  0.,  2., 11., 12., 16.,
#        16.,  5.,  0.,  0.,  0.,  0.,  0., 14., 15.,  2.,  0.,  0.,  0.,
#         0.,  1., 16., 11.,  0.,  0.,  0.,  0.,  0.,  0., 14., 14.,  0.,
#         0.,  0.,  0.,  0.,  0.,  5., 16.,  9.,  0.,  0.,  0.,  3.,  7.,
#        12., 16.,  7.,  0.,  0.,  3., 16., 16., 15., 11.,  1.,  0.])

# %%
digits.target[143]
# Out:
# 3

# %%
x=digits.data
y=digits.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=20)

# %%
model=RandomForestClassifier(n_estimators=23,random_state=90)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9711111111111111

# %%
pred=model.predict(x_test)
pred
# Out:
# array([0, 7, 9, 5, 8, 1, 3, 3, 7, 0, 9, 4, 7, 4, 0, 3, 1, 8, 1, 3, 7, 8,
#        4, 6, 1, 0, 1, 0, 5, 4, 7, 1, 6, 7, 8, 4, 3, 7, 4, 0, 5, 9, 0, 4,
#        8, 7, 4, 3, 6, 3, 9, 2, 2, 5, 7, 3, 7, 2, 3, 8, 6, 6, 0, 6, 8, 5,
#        0, 5, 3, 5, 0, 7, 3, 2, 9, 9, 3, 0, 2, 5, 5, 9, 2, 4, 5, 9, 7, 7,
#        2, 8, 0, 4, 6, 1, 9, 7, 1, 9, 9, 3, 4, 6, 7, 8, 1, 8, 4, 0, 1, 3,
#        6, 3, 5, 5, 1, 6, 0, 6, 2, 8, 9, 4, 1, 3, 4, 0, 6, 7, 7, 9, 8, 7,
#        8, 2, 4, 2, 5, 2, 3, 8, 8, 9, 8, 0, 0, 6, 2, 6, 9, 0, 9, 0, 0, 8,
#        7, 5, 3, 4, 0, 5, 6, 2, 6, 0, 4, 8, 7, 9, 2, 4, 3, 6, 4, 4, 5, 2,
#        8, 0, 7, 7, 3, 2, 2, 9, 0, 7, 2, 1, 6, 7, 9, 1, 5, 1, 6, 4, 6, 1,
#        3, 6, 1, 0, 8, 6, 5, 8, 8, 9, 1, 5, 1, 2, 6, 7, 5, 0, 1, 2, 4, 7,
#        0, 9, 6, 4, 7, 6, 5, 1, 2, 5, 5, 4, 6, 1, 7, 6, 1, 8, 9, 6, 2, 8,
#        5, 8, 3, 3, 9, 0, 3, 7, 9, 9, 1, 7, 0, 0, 5, 7, 3, 6, 3, 8, 6, 3,
#        6, 9, 8, 3, 3, 4, 4, 0, 7, 1, 5, 6, 1, 4, 6, 4, 5, 6, 3, 7, 9, 5,
# ...
